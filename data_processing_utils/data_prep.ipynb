# %%
import pandas as pd

df_test = pd.read_pickle('/home/nroethler/Code/abhiram/chemmap/AffinityPred/processed_data/test_processed.pkl')[['protein_embedding', 'graph', 'pChEMBL Value']]
df_train = pd.read_pickle('/home/nroethler/Code/abhiram/chemmap/AffinityPred/processed_data/train_processed.pkl')[['protein_embedding', 'graph', 'pChEMBL Value']]
df_valid = pd.read_pickle('/home/nroethler/Code/abhiram/chemmap/AffinityPred/processed_data/valid_processed.pkl')[['protein_embedding', 'graph', 'pChEMBL Value']]
# df = df[['Smiles', 'Sequence', 'pChEMBL Value']]

df_test.to_parquet("/home/nroethler/Code/abhiram/chemmap/AffinityPred/processed_data/test_processed.parquet", index=False)
df_train.to_parquet("/home/nroethler/Code/abhiram/chemmap/AffinityPred/processed_data/train_processed.parquet", index=False)
df_valid.to_parquet("/home/nroethler/Code/abhiram/chemmap/AffinityPred/processed_data/valid_processed.parquet", index=False)
df_test.head(5)
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[11], line 8
#       5 df_valid = pd.read_pickle('/home/nroethler/Code/abhiram/chemmap/AffinityPred/processed_data/valid_processed.pkl')[['protein_embedding', 'graph', 'pChEMBL Value']]
#       6 # df = df[['Smiles', 'Sequence', 'pChEMBL Value']]
# ----> 8 df_test.to_parquet("/home/nroethler/Code/abhiram/chemmap/AffinityPred/processed_data/test_processed.parquet", index=False)
#       9 df_train.to_parquet("/home/nroethler/Code/abhiram/chemmap/AffinityPred/processed_data/train_processed.parquet", index=False)
#      10 df_valid.to_parquet("/home/nroethler/Code/abhiram/chemmap/AffinityPred/processed_data/valid_processed.parquet", index=False)
#
# File ~/miniconda3/envs/gen_ca/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
import pandas as pd
df_valid = pd.read_pickle('/home/nroethler/Code/abhiram/chemmap/AffinityPred/processed_data/valid_processed.pkl')[['protein_embedding', 'graph', 'pChEMBL Value']]

# %%
import networkx as nx
import matplotlib.pyplot as plt
import py3Dmol
from rdkit.Chem import rdMolTransforms
import dgl


def visualize_graph_2d(graph):
    nx_g = dgl.to_networkx(graph, node_attrs=['feat'], edge_attrs=['feat'])
    pos = nx.spring_layout(nx_g)
    labels = {i: f'{i}' for i in range(graph.number_of_nodes())}

    plt.figure(figsize=(8, 8))
    nx.draw(nx_g, pos, with_labels=True, labels=labels, node_color='skyblue', edge_color='gray', node_size=500, font_size=10)
    plt.title("Graph Visualization (2D)")
    plt.show()

visualize_graph_2d(df.head(1)['graph'].iloc[0])
